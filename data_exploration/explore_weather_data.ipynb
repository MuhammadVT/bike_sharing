# %% [markdown]
# # Explore _weather_ Data

# %% [markdown]
# In this short report we explore the _weather_ data.

# %%
# load necessary packages
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
from IPython.display import display

# %%
# show the figures within the notebook
# %matplotlib inline

# Select ggplot as style
plt.style.use("ggplot")

# %% [markdown]
# ## Display the data

# %%
# read the data
df_weather = pd.read_csv("../data/weather.csv", parse_dates=["date"])

# display the data
display(df_weather.head())

# show the number of data points in trip.csv
print("This table has {npnts} data points and {col} columns.".format(npnts=df_weather.shape[0], col=df_weather.shape[1]))

# display the features
print("\nThe columns in this dataset are:")
print("".join([str(i+1) + ". " + df_weather.columns[i]+"\n" for i in range(len(df_weather.columns))]))

# types of events
print("\nThe types of weather events in the 'events' column are:")
evnts = [str(x) for x in df_weather.events.unique()]
print("".join([str(i+1) + ". " + evnts[i] + "\n" for i in range(len(evnts))]))
# Out:
#         date  max_temperature_f  mean_temperature_f  min_temperature_f  \
# 0 2013-08-29               74.0                68.0               61.0
# 1 2013-08-30               78.0                69.0               60.0
# 2 2013-08-31               71.0                64.0               57.0
# 3 2013-09-01               74.0                66.0               58.0
# 4 2013-09-02               75.0                69.0               62.0
#
#    max_dew_point_f  mean_dew_point_f  min_dew_point_f  max_humidity  \
# 0             61.0              58.0             56.0          93.0
# 1             61.0              58.0             56.0          90.0
# 2             57.0              56.0             54.0          93.0
# 3             60.0              56.0             53.0          87.0
# 4             61.0              60.0             58.0          93.0
#
#    mean_humidity  min_humidity   ...     mean_visibility_miles  \
# 0           75.0          57.0   ...                      10.0
# 1           70.0          50.0   ...                      10.0
# 2           75.0          57.0   ...                      10.0
# 3           68.0          49.0   ...                      10.0
# 4           77.0          61.0   ...                      10.0
#
#    min_visibility_miles  max_wind_Speed_mph  mean_wind_speed_mph  \
# 0                  10.0                23.0                 11.0
# 1                   7.0                29.0                 13.0
# 2                  10.0                26.0                 15.0
# 3                  10.0                25.0                 13.0
# 4                   6.0                23.0                 12.0
#
#    max_gust_speed_mph  precipitation_inches  cloud_cover  events  \
# 0                28.0                     0          4.0     NaN
# 1                35.0                     0          2.0     NaN
# 2                31.0                     0          4.0     NaN
# 3                29.0                     0          4.0     NaN
# 4                30.0                     0          6.0     NaN
#
#    wind_dir_degrees zip_code
# 0             286.0    94107
# 1             291.0    94107
# 2             284.0    94107
# 3             284.0    94107
# 4             277.0    94107
#
# [5 rows x 24 columns]
# This table has 3665 data points and 24 columns.
#
# The columns in this dataset are:
# 1. date
# 2. max_temperature_f
# 3. mean_temperature_f
# 4. min_temperature_f
# 5. max_dew_point_f
# 6. mean_dew_point_f
# 7. min_dew_point_f
# 8. max_humidity
# 9. mean_humidity
# 10. min_humidity
# 11. max_sea_level_pressure_inches
# 12. mean_sea_level_pressure_inches
# 13. min_sea_level_pressure_inches
# 14. max_visibility_miles
# 15. mean_visibility_miles
# 16. min_visibility_miles
# 17. max_wind_Speed_mph
# 18. mean_wind_speed_mph
# 19. max_gust_speed_mph
# 20. precipitation_inches
# 21. cloud_cover
# 22. events
# 23. wind_dir_degrees
# 24. zip_code
#
#
# The types of weather events in the 'events' column are:
# 1. nan
# 2. Fog
# 3. Rain
# 4. Fog-Rain
# 5. rain
# 6. Rain-Thunderstorm

# %%
# Produce a scatter matrix for each pair of features in the data
dfn = df_weather.iloc[:, [1,2,3]]
pd.plotting.scatter_matrix(dfn, alpha = 0.5, figsize = (14,8), diagonal = 'kde');

# %%
# create a figure
fig, ax = plt.subplots()

ax.matshow(df_weather.corr())

# %%
df_weather.corr().head()
# Out:
#                     max_temperature_f  mean_temperature_f  min_temperature_f  \
# max_temperature_f            1.000000            0.911053           0.642262
# mean_temperature_f           0.911053            1.000000           0.895589
# min_temperature_f            0.642262            0.895589           1.000000
# max_dew_point_f              0.591009            0.762283           0.806454
# mean_dew_point_f             0.499557            0.725385           0.832147
#
#                     max_dew_point_f  mean_dew_point_f  min_dew_point_f  \
# max_temperature_f          0.591009          0.499557         0.390628
# mean_temperature_f         0.762283          0.725385         0.637523
# min_temperature_f          0.806454          0.832147         0.786409
# max_dew_point_f            1.000000          0.941917         0.839875
# mean_dew_point_f           0.941917          1.000000         0.951657
#
#                     max_humidity  mean_humidity  min_humidity  \
# max_temperature_f      -0.219896      -0.381374     -0.425543
# mean_temperature_f     -0.130001      -0.159278     -0.143710
# min_temperature_f      -0.019074       0.118202      0.196069
# max_dew_point_f         0.383585       0.397418      0.339585
# mean_dew_point_f        0.416650       0.498571      0.490304
#
#                     max_sea_level_pressure_inches    ...     \
# max_temperature_f                       -0.439260    ...
# mean_temperature_f                      -0.576604    ...
# min_temperature_f                       -0.617008    ...
# max_dew_point_f                         -0.511553    ...
# mean_dew_point_f                        -0.539326    ...
#
#                     min_sea_level_pressure_inches  max_visibility_miles  \
# max_temperature_f                       -0.351647              0.110215
# mean_temperature_f                      -0.471856              0.141461
# min_temperature_f                       -0.514509              0.153249
# max_dew_point_f                         -0.439690              0.168397
# mean_dew_point_f                        -0.450946              0.173421
#
#                     mean_visibility_miles  min_visibility_miles  \
# max_temperature_f                0.249346              0.338524
# mean_temperature_f               0.228928              0.258529
# min_temperature_f                0.164550              0.120792
# max_dew_point_f                  0.089170             -0.044869
# mean_dew_point_f                 0.070216             -0.059679
#
#                     max_wind_Speed_mph  mean_wind_speed_mph  \
# max_temperature_f             0.085921             0.065908
# mean_temperature_f            0.176267             0.284047
# min_temperature_f             0.240461             0.446882
# max_dew_point_f               0.154593             0.242775
# mean_dew_point_f              0.171648             0.327118
#
#                     max_gust_speed_mph  cloud_cover  wind_dir_degrees  \
# max_temperature_f            -0.025636    -0.306980          0.218716
# mean_temperature_f            0.060642    -0.040139          0.168771
# min_temperature_f             0.152553     0.251094          0.091643
# max_dew_point_f               0.091348     0.218810          0.100538
# mean_dew_point_f              0.088838     0.330047          0.074544
#
#                     zip_code
# max_temperature_f   0.111282
# mean_temperature_f  0.051920
# min_temperature_f  -0.049098
# max_dew_point_f    -0.074265
# mean_dew_point_f   -0.054598
#
# [5 rows x 21 columns]
